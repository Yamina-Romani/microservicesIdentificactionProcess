# %% [markdown]
# <a href="https://colab.research.google.com/github/Yamina-Romani/microservices_identificaction_example/blob/main/Broadleaf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Titre par défaut
import os
import string
import matplotlib
import matplotlib_inline
import numpy as np
import pandas as pd
import gensim.models
import nltk
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn import metrics 
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#print('Indexing word vectors.')

embeddings_index = {}
f = open('/content/drive/My Drive/glove.6B.50d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

#print('Found %s word vectors.' % len(embeddings_index))

# %%
embeddings_dict={}
with open('/content/drive/My Drive/glove.6B.50d.txt','rb') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
nltk.download('stopwords')
nltk.download('wordnet')
#    stop words
stop_words = set(stopwords.words('english'))

# punctuation
punctuation = set(string.punctuation)

# lemmatization

lemmatization = WordNetLemmatizer()

def clean(documents):
    # split documents and remove stop words

    split_doc = " ".join([i for i in documents.lower().split() if i not in stop_words])

    # remove punctuation
    punc_doc = ''.join([j for j in split_doc if j not in punctuation])

    # normalize the text
    normalized = " ".join([lemmatization.lemmatize(word) for word in punc_doc.split()])

    return normalized
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# .........................getSynonyms using wordnet.................................................................................;
nltk.download('wordnet')
def getSynonyms(name):
    # print("name is " ,name)
    name = name.replace('_', ' ')
    syn = []
    ant = []
    for word in name.split():
        if word != "blc":
            for synset in wordnet.synsets(word):
                for lemma in synset.lemmas():
                    if (str(lemma.name()).lower() not in syn) and (str(lemma.name()).lower() != word) and (len(syn)<6):
                        syn.append(str(lemma.name()).lower())  # add the synonyms
                        if lemma.antonyms():  # When antonyms are available, add them into the list
                            ant.append(lemma.antonyms()[0].name())
    #  print('Synonyms: ' + str(syn))
    # print('Antonyms: ' + str(ant))
    return syn
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# ............Foreign keys......................................................................................................
def ObtainForeinKeys(lines):
    punc = '''!()-[]{};:'"\,<>.?@#$%^&=~'''

    listKeys = []
    Data = []
    for line in lines:
        doc = ''.join(ch for ch in line if ch not in punc)
        doc = doc.replace('|', ' ')
        Split_Doc = [word for word in doc.split() if word not in punc]
        if Split_Doc:
            Data.append(Split_Doc)

    i = 0
    for i in range(0, len(Data)):
        if (i in range(0, len(Data))) and (Data[i][0] == "Colonne"):
            Data.remove(Data[i])

        if (i in range(0, len(Data))) and (Data[i][0] == "Base"):
            Data.remove(Data[i])

        if (i in range(0, len(Data))) and (Data[i][0] == "Déchargement"):
            # print("i = ", i, "size = ",len(Data)," line ",Data[i])
            while (i in range(0, len(Data))) and (Data[i][0] != "Structure"):
                # print("\n line : ", Data[i])
                Data.remove(Data[i])

    cpt = 0
    list = []
    for doc in Data:

        if doc[0] == "Structure":
            i = 1
            if len(list) != 0:
                listKeys.append(list)
                list = []

            while doc[i] != "table":
                i = i + 1
            # print("cpt: ", cpt, " i : ", doc[i], " ", doc[i + 1])
            list.append(doc[i + 1])

        else:
            if "//**" not in doc[0] and ("Id" in doc[0] or "ID" in doc[0] or "id" in doc[0]):
                doc[0] = doc[0].replace("/", "")
                doc[0] = doc[0].replace("*", "")
                list.append(doc[0])

    return listKeys

# %%
# .........................Primary keys.............................................................................................
def ObtainPrimaryKeys(lines):
    punc = '''!()-[]{};:'"\,<>.?@#$%^&=~'''

    listKeys = []
    Data = []
    for line in lines:
        doc = ''.join(ch for ch in line if ch not in punc)
        doc = doc.replace('|', ' ')
        Split_Doc = [word for word in doc.split() if word not in punc]
        if Split_Doc:
            Data.append(Split_Doc)

    i = 0
    for i in range(0, len(Data)):
        if (i in range(0, len(Data))) and (Data[i][0] == "Colonne"):
            Data.remove(Data[i])

        if (i in range(0, len(Data))) and (Data[i][0] == "Base"):
            Data.remove(Data[i])

        if (i in range(0, len(Data))) and (Data[i][0] == "Déchargement"):
            # print("i = ", i, "size = ",len(Data)," line ",Data[i])
            while (i in range(0, len(Data))) and (Data[i][0] != "Structure"):
                # print("\n line : ", Data[i])
                Data.remove(Data[i])

    cpt = 0
    list = []
    for doc in Data:

        if doc[0] == "Structure":
            i = 1
            if len(list) != 0:
                listKeys.append(list)
                list = []

            while doc[i] != "table":
                i = i + 1
            # print("cpt: ", cpt, " i : ", doc[i], " ", doc[i + 1])
            list.append(doc[i + 1])

        else:
            if "//**" in doc[0]:
                doc[0] = doc[0].replace("/", "")
                doc[0] = doc[0].replace("*", "")
                list.append(doc[0])

    return listKeys

# %%
# ............................  Extract Symbols ..................................................................
def Extract(file_name):
    file='/content/drive/My Drive/'+file_name+'.txt'
    file = open(file, "r", encoding='UTF8')
    lines = file.readlines()
    file.close()
    ForeigKeys = []
    PrimaryKeys = []
    Tables_name = []
    PrimaryKeys = ObtainPrimaryKeys(lines)
    ForeigKeys = ObtainForeinKeys(lines)
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*~='''
    Data = []
    for line in lines:
        doc = ''.join(ch for ch in line if ch not in punc)
        doc = doc.replace('|', ' ')
        Split_Doc = [word for word in doc.split() if (word not in punc)]

        if Split_Doc:
            Data.append(Split_Doc)

    i = 0
    for i in range(0, len(Data)):
        if (i in range(0, len(Data))) and (Data[i][0] == "Colonne"):
            Data.remove(Data[i])

        if (i in range(0, len(Data))) and (Data[i][0] == "Base"):
            Data.remove(Data[i])

        if (i in range(0, len(Data))) and (Data[i][0] == "Déchargement"):
            # print("i = ", i, "size = ",len(Data)," line ",Data[i])
            while (i in range(0, len(Data))) and (Data[i][0] != "Structure"):
                # print("\n line : ", Data[i])
                Data.remove(Data[i])

    # ................. Extract Symbols ..................................

    # print("Data:")
    File_name = '/content/drive/My Drive/'+file_name+'_treat.txt'
    Synonyms = []
    TargetTable = []
    f = open(File_name, "w")
    for doc in Data:
        cpt = 0
        if doc[0] == "Structure":
            i = 1
            while doc[i] != "table":
                i = i + 1

            name = doc[i + 1]
            Tables_name.append(name)
            Synonyms = getSynonyms(name)
            
            f.write("\n" + doc[i + 1].replace('_', ' ') + " " + doc[i + 1].replace('_', ' ') + " " + doc[i + 1].replace('_',
                                                                                                                    ' ') + ": ")
            for s in Synonyms:
                f.write(s.replace('_', ' ') + ", ")
        else:
            if "ID" in doc[0] or "id" in doc[0] or "Id" in doc[0]:
                # print("tab = ", name)
                f.write(doc[0].replace('_', ' ').lower() + ", ")
                # if Foreign Key
                NoneSengletobFKey = False
                IsForeignKey = False
                for k in ForeigKeys:
                    #  print("k = ",k[0], "name = ",name)
                    if k[0] == name and doc[0] in k:
                        IsForeignKey = True
                    if k[0] != name and doc[0] in k:
                        NoneSengletobFKey = True

                PrimaryKey = False
                sourceTable = ""
                if IsForeignKey:  # is Foreign key
                    for k in PrimaryKeys:
                        if len(k) == 2 and k[1] == doc[0]:
                            sourceTable = k[0]
                        if len(k) > 2 and doc[0] in k:
                            PrimaryKey = True

                    # print( "key",doc[0] ,"Senelton = ", NoneSengletobFKey)
                    if not NoneSengletobFKey and not PrimaryKey and sourceTable != "":
                        for i in range(3):
                            f.write(doc[0].replace('_', ' ').lower() + ", " + doc[0].replace('_', ' ').lower() + ", ")
                            f.write(sourceTable.replace('_', ' ') + ", " + sourceTable.replace('_',
                                                                                               ' ') + ", " + sourceTable.replace(
                                '_', ' ') + ", ")
                    else:
                        if sourceTable != "":
                            for i in range(3):
                                f.write(doc[0].replace('_', ' ').lower() + ", ")
                                f.write(sourceTable.replace('_', ' ') + ", " + sourceTable.replace('_', ' ') + ", ")
                else:  # is not a foreign key

                    oneKey = False
                    twoKey = False
                    for k in PrimaryKeys:
                        if k[0] == name and len(k) == 2 and k[1] == doc[0]:
                            oneKey = True
                        if k[0] == name and len(k) > 2 and doc[0] in k:
                            twoKey = True
                    if oneKey:  # if one primary key
                        TargetTable = []
                        for k in PrimaryKeys:
                            if k[0] != name and doc[0] in k:
                                TargetTable.append(k[0])

                        for k in ForeigKeys:
                            if k[0] != name and doc[0] in k:
                                TargetTable.append(k[0])

                        # print('target tabel of ',name, " are: ",TargetTable)
                        if len(TargetTable) == 1:
                            for i in range(3):
                                f.write(
                                    TargetTable[0].replace('_', ' ') + ", " + TargetTable[0].replace('_', ' ') + ", " +
                                    TargetTable[0].replace('_', ' ') + ", ")
                        if len(TargetTable) > 1:
                            for i in range(len(TargetTable)):
                                for j in range(3):
                                    f.write(TargetTable[i].replace('_', ' ') + ", " + TargetTable[i].replace('_',
                                                                                                             ' ') + ", ")

                    if twoKey:  # if two primary key
                        SourceTable = ""
                        existInOthers = False
                        for k in PrimaryKeys:
                            if k[0] != name and len(k) == 2 and doc[0] in k:
                                SourceTable = k[0]
                            if k[0] != name and len(k) > 2 and doc[0] in k:
                                existInOthers = True
                        existFKey = False
                        for k in ForeigKeys:
                            if k[0] != name and doc[0] in k:
                                existFKey = True
                        if not existInOthers and not existFKey and SourceTable != "":
                            for i in range(3):
                                f.write(doc[0].replace('_', ' ').lower() + ", " + doc[0].replace('_', ' ').lower() + ", ")
                                f.write(SourceTable.replace('_', ' ') + ", " + SourceTable.replace('_',
                                                                                                   ' ') + ", " + SourceTable.replace(
                                    '_', ' ') + ", ")
                        else:
                            if SourceTable != "":
                                for i in range(3):
                                    f.write(doc[0].replace('_', ' ').lower() + ", ")
                                    f.write(SourceTable.replace('_', ' ') + ", " + SourceTable.replace('_', ' ') + ", ")

            else:
                f.write(doc[0].replace('_', ' ').lower() + ", ")

    f.close()
    information = []
    information.append(File_name)
    information.append(Tables_name)
    return information

# %%
nltk.download('omw-1.4')
name = input("The file name : ") 

information = []
information = Extract(name)
File = information[0]
Tabels_name = information[1]
corpus = open(File, "r")
#corpus=open('/content/drive/MyDrive/autoparts.txt',"r")
clean_documents = [clean(doc) for doc in corpus]

#print(clean_documents)
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# The file name : broadleaf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
documents=[]
for doc in clean_documents:
   # print("doc = ",doc.split())
    documents.append(doc.split())
#print(documents)
with open('/content/drive/My Drive/docs.txt', 'w') as writefile:
     for doc in documents:
         writefile.write(str(doc))

# %%
def calculate_Document_vector(document,j):

 
 vectors=[]

 for word in document:
     #print("word :", word)
     if(word in embeddings_index):
        vectors.append(embeddings_index[word])

 avearge_vector=[]
 
 #print("length = ",len(vectors))
 i=0
 for i in range(50):   
     mean=0
     for vect in vectors:
        mean=mean+vect[i]
        #print("doc",j, " i = ",i)

     avearge_vector.append(mean/len(vectors))

 return(avearge_vector)


     
matrix=[]

documents=[]
j=0
for doc in clean_documents:
    #print("doc = ",doc.split())
    j=j+1
    if(doc!=''):
      documents.append(doc.split())
      DocVector=calculate_Document_vector(doc.split(),j)
      #print(DocVector)
      matrix.append(DocVector)


#print("doucument's vectors :",matrix)   

with open('/content/drive/My Drive/docsVector.txt', 'w') as writefile:
     for v in matrix:
         writefile.write(str(v))

# %%
#print(matrix)

# %%
# .........................elbow method..................
wcss = []  # WCSS Scores = within-cluster-sum of squared distance
c=int(input("The namber of clusters : "))
clusters_1 = range(2, c)
for i in clusters_1:
    kmeans = KMeans(n_clusters=i, init='random', max_iter=300, n_init=30, algorithm="elkan",random_state=77)
    kmeans.fit(matrix)
    labels = kmeans.labels_
    result=davies_bouldin_score(matrix, labels)
  #  print( "metric davies_bouldin with  ","c =",i,"est: ", result)
    result=metrics.calinski_harabasz_score(matrix, labels)
   # print( "metric calinski_harabasz =  ","c =",i,"est: ", result)

    wcss.append(kmeans.inertia_)
plt.style.use("seaborn")
plt.plot(range(2, c), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-Cluster-Sum of Squared Distance')
plt.show()
# Out:
# The namber of clusters : 45

# %%
# ........... ............. k means ............................................................................................
clusters = int((input("The namber of clusters : "))) # modified 

model = KMeans(n_clusters=clusters, init="k-means++", max_iter=300, n_init=30, algorithm="elkan", random_state=77)

model.fit(matrix)

order_centroids = model.cluster_centers_.argsort()[:, ::-1]

# Getting the Centroids
centroids = kmeans.cluster_centers_
labels = model.labels_
result=davies_bouldin_score(matrix, labels)
print( "metric davies_bouldin =  ", result)
result=metrics.calinski_harabasz_score(matrix, labels)
print( "metric calinski_harabasz =  ", result)


#............Obtained Clusters..........................................................................................
obtainesCluster = []
for c in range(clusters):
    print(" Cluster", c)
    print("__________________________________________")
    count = 0
    cluseterI = []
    cluseterI.append(c)
    for i in labels:

        if i == c and count < len(Tabels_name):
            print("Table: ", Tabels_name[count], " ---> Document ", count)
            cluseterI.append(Tabels_name[count])
        count = count + 1

    obtainesCluster.append(cluseterI)
    print("__________________________________________")
# Out:
# The namber of clusters : 20
# metric davies_bouldin =   1.3637603267660983
# metric calinski_harabasz =   15.086443344788838
#  Cluster 0
# __________________________________________
# Table:  blc_country  ---> Document  36
# Table:  blc_country_sub  ---> Document  37
# Table:  blc_country_sub_cat  ---> Document  38
# Table:  blc_iso_country  ---> Document  83
# Table:  blc_state  ---> Document  174
# Table:  blc_system_property  ---> Document  179
# __________________________________________
#  Cluster 1
# __________________________________________
# Table:  blc_category  ---> Document  24
# Table:  blc_category_attribute  ---> Document  25
# Table:  blc_category_product_xref  ---> Document  27
# Table:  blc_category_xref  ---> Document  28
# Table:  blc_product  ---> Document  123
# Table:  blc_product_attribute  ---> Document  124
# Table:  blc_product_bundle  ---> Document  125
# Table:  blc_product_cross_sale  ---> Document  126
# Table:  blc_product_featured  ---> Document  127
# Table:  blc_product_option  ---> Document  128
# Table:  blc_product_option_value  ---> Document  129
# Table:  blc_product_option_xref  ---> Document  130
# Table:  blc_product_up_sale  ---> Document  131
# Table:  blc_sku_option_value_xref  ---> Document  173
# __________________________________________
#  Cluster 2
# __________________________________________
# Table:  blc_additional_offer_info  ---> Document  0
# Table:  blc_candidate_item_offer  ---> Document  21
# Table:  blc_candidate_order_offer  ---> Document  22
# Table:  blc_challenge_question  ---> Document  32
# Table:  blc_item_offer_qualifier  ---> Document  84
# Table:  blc_offer  ---> Document  88
# Table:  blc_offer_audit  ---> Document  89
# Table:  blc_offer_code  ---> Document  90
# Table:  blc_offer_info  ---> Document  91
# Table:  blc_offer_info_fields  ---> Document  92
# Table:  blc_offer_price_data  ---> Document  94
# Table:  blc_offer_rule  ---> Document  95
# Table:  blc_offer_rule_map  ---> Document  96
# Table:  blc_personal_message  ---> Document  120
# Table:  blc_qual_crit_offer_xref  ---> Document  134
# Table:  blc_search_intercept  ---> Document  156
# Table:  blc_tar_crit_offer_xref  ---> Document  180
# __________________________________________
#  Cluster 3
# __________________________________________
# Table:  blc_email_tracking  ---> Document  56
# Table:  blc_email_tracking_clicks  ---> Document  57
# Table:  blc_email_tracking_opens  ---> Document  58
# __________________________________________
#  Cluster 4
# __________________________________________
# Table:  blc_asset_desc_map  ---> Document  16
# Table:  blc_img_static_asset  ---> Document  80
# Table:  blc_static_asset  ---> Document  175
# Table:  blc_static_asset_desc  ---> Document  176
# Table:  blc_static_asset_strg  ---> Document  177
# Table:  blc_userconnection  ---> Document  185
# __________________________________________
#  Cluster 5
# __________________________________________
# Table:  blc_candidate_fg_offer  ---> Document  20
# Table:  blc_fg_adjustment  ---> Document  59
# Table:  blc_fg_fee_tax_xref  ---> Document  60
# Table:  blc_fg_fg_tax_xref  ---> Document  61
# Table:  blc_fg_item_tax_xref  ---> Document  62
# Table:  blc_fulfillment_group  ---> Document  68
# Table:  blc_fulfillment_group_fee  ---> Document  69
# Table:  blc_fulfillment_group_item  ---> Document  70
# Table:  blc_fulfillment_option  ---> Document  71
# Table:  blc_fulfillment_option_fixed  ---> Document  72
# Table:  blc_fulfillment_opt_banded_prc  ---> Document  73
# Table:  blc_fulfillment_opt_banded_wgt  ---> Document  74
# Table:  blc_fulfillment_price_band  ---> Document  75
# Table:  blc_fulfillment_weight_band  ---> Document  76
# Table:  blc_offer_item_criteria  ---> Document  93
# Table:  blc_order_payment_transaction  ---> Document  111
# Table:  blc_tax_detail  ---> Document  181
# __________________________________________
#  Cluster 6
# __________________________________________
# Table:  blc_fld_group  ---> Document  67
# Table:  blc_qual_crit_sc_xref  ---> Document  136
# Table:  blc_sc  ---> Document  144
# Table:  blc_sc_fld  ---> Document  145
# Table:  blc_sc_fldgrp_xref  ---> Document  146
# Table:  blc_sc_fld_map  ---> Document  147
# Table:  blc_sc_fld_tmplt  ---> Document  148
# Table:  blc_sc_item_criteria  ---> Document  149
# Table:  blc_sc_rule  ---> Document  150
# Table:  blc_sc_rule_map  ---> Document  151
# Table:  blc_sc_type  ---> Document  152
# __________________________________________
#  Cluster 7
# __________________________________________
# Table:  blc_data_drvn_enum  ---> Document  51
# Table:  blc_fld_def  ---> Document  64
# Table:  blc_fld_enum  ---> Document  65
# Table:  blc_fld_enum_item  ---> Document  66
# Table:  blc_sandbox_mgmt  ---> Document  143
# Table:  blc_sku  ---> Document  164
# Table:  blc_sku_attribute  ---> Document  165
# Table:  blc_sku_availability  ---> Document  166
# Table:  blc_sku_bundle_item  ---> Document  167
# Table:  blc_sku_fee  ---> Document  168
# Table:  blc_sku_fee_xref  ---> Document  169
# Table:  blc_sku_fulfillment_excluded  ---> Document  170
# Table:  blc_sku_fulfillment_flat_rates  ---> Document  171
# __________________________________________
#  Cluster 8
# __________________________________________
# Table:  blc_admin_module  ---> Document  2
# Table:  blc_admin_password_token  ---> Document  3
# Table:  blc_admin_permission  ---> Document  4
# Table:  blc_admin_permission_entity  ---> Document  5
# Table:  blc_admin_permission_xref  ---> Document  6
# Table:  blc_admin_role  ---> Document  7
# Table:  blc_admin_role_permission_xref  ---> Document  8
# Table:  blc_admin_section  ---> Document  9
# Table:  blc_admin_sec_perm_xref  ---> Document  10
# Table:  blc_admin_user  ---> Document  11
# Table:  blc_admin_user_addtl_fields  ---> Document  12
# Table:  blc_admin_user_permission_xref  ---> Document  13
# Table:  blc_admin_user_role_xref  ---> Document  14
# Table:  blc_admin_user_sandbox  ---> Document  15
# Table:  blc_sandbox  ---> Document  142
# Table:  blc_url_handler  ---> Document  184
# __________________________________________
#  Cluster 9
# __________________________________________
# Table:  blc_cat_search_facet_excl_xref  ---> Document  29
# Table:  blc_cat_search_facet_xref  ---> Document  30
# Table:  blc_data_drvn_enum_val  ---> Document  52
# Table:  blc_id_generation  ---> Document  79
# Table:  blc_locale  ---> Document  85
# Table:  blc_search_facet  ---> Document  153
# Table:  blc_search_facet_range  ---> Document  154
# Table:  blc_search_facet_xref  ---> Document  155
# Table:  blc_search_synonym  ---> Document  157
# Table:  blc_shipping_rate  ---> Document  158
# Table:  blc_zip_code  ---> Document  186
# __________________________________________
#  Cluster 10
# __________________________________________
# Table:  blc_bank_account_payment  ---> Document  17
# Table:  blc_credit_card_payment  ---> Document  39
# Table:  blc_customer_payment_fields  ---> Document  47
# Table:  blc_gift_card_payment  ---> Document  78
# Table:  blc_payment_log  ---> Document  119
# Table:  blc_trans_additnl_fields  ---> Document  183
# __________________________________________
#  Cluster 11
# __________________________________________
# Table:  blc_catalog  ---> Document  23
# Table:  blc_site  ---> Document  159
# Table:  blc_site_catalog  ---> Document  160
# __________________________________________
#  Cluster 12
# __________________________________________
# Table:  blc_category_media_map  ---> Document  26
# Table:  blc_cms_menu  ---> Document  33
# Table:  blc_cms_menu_item  ---> Document  34
# Table:  blc_media  ---> Document  86
# Table:  blc_promotion_message  ---> Document  132
# Table:  blc_sku_media_map  ---> Document  172
# __________________________________________
#  Cluster 13
# __________________________________________
# Table:  blc_cat_site_map_gen_cfg  ---> Document  31
# Table:  blc_cust_site_map_gen_cfg  ---> Document  50
# Table:  blc_module_configuration  ---> Document  87
# Table:  blc_site_map_cfg  ---> Document  161
# Table:  blc_site_map_gen_cfg  ---> Document  162
# Table:  blc_site_map_url_entry  ---> Document  163
# __________________________________________
#  Cluster 14
# __________________________________________
# Table:  blc_rating_detail  ---> Document  137
# Table:  blc_rating_summary  ---> Document  138
# Table:  blc_review_detail  ---> Document  139
# Table:  blc_review_feedback  ---> Document  140
# __________________________________________
#  Cluster 15
# __________________________________________
# Table:  blc_field  ---> Document  63
# Table:  blc_index_field  ---> Document  81
# Table:  blc_index_field_type  ---> Document  82
# __________________________________________
#  Cluster 16
# __________________________________________
# Table:  blc_page  ---> Document  112
# Table:  blc_page_attributes  ---> Document  113
# Table:  blc_page_fld  ---> Document  114
# Table:  blc_page_item_criteria  ---> Document  115
# Table:  blc_page_rule  ---> Document  116
# Table:  blc_page_rule_map  ---> Document  117
# Table:  blc_page_tmplt  ---> Document  118
# Table:  blc_pgtmplt_fldgrp_xref  ---> Document  121
# Table:  blc_qual_crit_page_xref  ---> Document  135
# __________________________________________
#  Cluster 17
# __________________________________________
# Table:  blc_code_types  ---> Document  35
# Table:  blc_translation  ---> Document  182
# Table:  sequence_generator  ---> Document  187
# __________________________________________
#  Cluster 18
# __________________________________________
# Table:  blc_bundle_order_item  ---> Document  18
# Table:  blc_bund_item_fee_price  ---> Document  19
# Table:  blc_currency  ---> Document  40
# Table:  blc_discrete_order_item  ---> Document  53
# Table:  blc_disc_item_fee_price  ---> Document  54
# Table:  blc_dyn_discrete_order_item  ---> Document  55
# Table:  blc_giftwrap_order_item  ---> Document  77
# Table:  blc_order  ---> Document  97
# Table:  blc_order_adjustment  ---> Document  98
# Table:  blc_order_attribute  ---> Document  99
# Table:  blc_order_item  ---> Document  100
# Table:  blc_order_item_add_attr  ---> Document  101
# Table:  blc_order_item_adjustment  ---> Document  102
# Table:  blc_order_item_attribute  ---> Document  103
# Table:  blc_order_item_cart_message  ---> Document  104
# Table:  blc_order_item_dtl_adj  ---> Document  105
# Table:  blc_order_item_price_dtl  ---> Document  106
# Table:  blc_order_lock  ---> Document  107
# Table:  blc_order_multiship_option  ---> Document  108
# Table:  blc_order_offer_code_xref  ---> Document  109
# Table:  blc_order_payment  ---> Document  110
# Table:  blc_prorated_order_item_adjust  ---> Document  133
# __________________________________________
#  Cluster 19
# __________________________________________
# Table:  blc_address  ---> Document  1
# Table:  blc_customer  ---> Document  41
# Table:  blc_customer_address  ---> Document  42
# Table:  blc_customer_attribute  ---> Document  43
# Table:  blc_customer_offer_xref  ---> Document  44
# Table:  blc_customer_password_token  ---> Document  45
# Table:  blc_customer_payment  ---> Document  46
# Table:  blc_customer_phone  ---> Document  48
# Table:  blc_customer_role  ---> Document  49
# Table:  blc_phone  ---> Document  122
# Table:  blc_role  ---> Document  141
# Table:  blc_store  ---> Document  178
# __________________________________________
